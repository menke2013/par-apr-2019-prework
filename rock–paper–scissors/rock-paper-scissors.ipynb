# %% [markdown]
# # Rock Paper Scissors
#
# Let's play the famous game against our computer.
#
# https://en.wikipedia.org/wiki/Rock%E2%80%93paper%E2%80%93scissors
#
# The use of functions is recommended
#
# ## Goals
# 1. Use of loop
# 2. Data capture by console
# 3. Use if-elif-else
# 4. Use of try-except
# 5. Definition of functions. Modular programming
# 6. Logical operators.
# 7. Print
# 8. Import modules

# %%
# Import the choice function of the random module
# https://stackoverflow.com/questions/306400/how-to-randomly-select-an-item-from-a-list

import random

# Assign to a list the 3 possible options: 'stone', 'paper' or 'scissors'.

list_of_choices = ["stone", "paper", "scissor"]


# Assign a variable to the maximum number of games: 1, 3, 5, etc ...

max_num_of_games = int(input("How many games do you want to play?:"))
while max_num_of_games %2 == 0:
    print ("You need an odd number of games! ")
    max_num_of_games = int(input("How many games do you want to play?:"))    


# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games

num_games_to_win_for_win = (max_num_of_games +1)/2
print("You have to win",int(num_games_to_win_for_win), "games")

# Define a function that randomly returns one of the 3 options.
# This will correspond to the play of the machine. Totally random.

def random_machine():
    return random.choice(list_of_choices)

# Define a function that asks your choice: 'stone', 'paper' or 'scissors'
# you should only allow one of the 3 options. This is defensive programming.
# If it is not stone, paper or scissors keep asking until it is.

def players_choice():
    pl_choi = input("stone, paper or scissor?:")
    while pl_choi not in list_of_choices:
        print("Option not available.Please choose again")
        pl_choi = input("stone, paper or scissor?:")
    return pl_choi




        
        

# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins

def combat(player,machine):
    if player == machine:
        return 0
    elif (player == "stone" and machine == "paper") or (player == "paper" and machine == "scissor") or (player == "scissor" and machine == "stone"):
        return 1
    else:
        return 2
   
  
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated

def game_progress(p,m):
    print("You chose", p, "and you have won", wins_player, "rounds")
    print("SkyNet chose", m, "and has won", wins_machine, "rounds")
    
# Create two variables that accumulate the wins of each participant

wins_player = 0
wins_machine = 0

# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.

while wins_player < num_games_to_win_for_win and wins_machine < num_games_to_win_for_win:
    player = players_choice()
    machine = random_machine()
    if combat(player,machine) == 1:
        wins_machine +=1
        game_progress (player,machine)
    elif combat(player,machine) == 2:
        wins_player +=1
        game_progress (player,machine)
    elif combat(player,machine) == 0:
        game_progress (player,machine)
        print("Nobody wins")


    
# Print by console the winner of the game based on who has more accumulated wins

if wins_player == num_games_to_win_for_win:
    print("The player wins!")
if wins_machine == num_games_to_win_for_win:
    print("SkyNet wins!")
# Out:
# How many games do you want to play?:3
# You have to win 2 games
# stone, paper or scissor?:stone
# You chose stone and you have won 1 rounds
# SkyNet chose scissor and has won 0 rounds
# stone, paper or scissor?:scissor
# You chose scissor and you have won 1 rounds
# SkyNet chose scissor and has won 0 rounds
# Nobody wins
# stone, paper or scissor?:scissor
# You chose scissor and you have won 1 rounds
# SkyNet chose scissor and has won 0 rounds
# Nobody wins
# stone, paper or scissor?:paper
# You chose paper and you have won 2 rounds
# SkyNet chose stone and has won 0 rounds
# The player wins!

# %% [markdown]
# # Bonus: Stone, paper, scissors, lizard, spock
#
# Now the improvement begins.
#
# ![](images/rpsls.jpg)
#
#
# http://www.samkass.com/theories/RPSSL.html
#
# You are asked to impliment some improvements with respect to the simple previous game. In addition, the number of games (which must be ODD) will be requested per console until a valid number is entered.
#
# Improvements:
# * 5 options: stone, paper, scissors, lizard, spock
# * The number of games is requested per console
# Tip: Reuse code that you already use. If you have programmed intelligently, the bonus are simple modifications to the original game.

# %%
# Import the choice function of the random module

import random


# Define a function that asks for an odd number on the keyboard, until it is not valid
# will keep asking

def number_of_g():
    max_num_of_games = int(input("How many games do you want to play?:"))
    while max_num_of_games %2 == 0:
        print ("You need an odd number of games! ")
        max_num_of_games = int(input("How many games do you want to play?:"))  
    return max_num_of_games
        
# Assign a list of 5 possible options.

list_of_choices = ["stone", "paper", "scissor","lizard","spock"]


# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
# This time the previously defined function is used

max_num_of_games_2 = number_of_g()

# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games

num_games_to_win_for_win = (max_num_of_games_2 +1)/2
print("You have to win" ,int(num_games_to_win_for_win),"games")


# Define a function that randomly returns one of the 5 options.
# This will correspond to the play of the machine. Totally random.

def random_machine():
    return random.choice(list_of_choices)

# Define a function that asks your choice between 5
# you should only allow one of the 5 options. This is defensive programming.
# If it is not valid, keep asking until it is valid.

def players_choice():
    pl_choi = input("stone, paper, lizard, spock or scissor?:")
    while pl_choi not in list_of_choices:
        print("Option not available.Please choose again")
        pl_choi = input("stone, paper, lizard, spock or scissor?:")
    return pl_choi



# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins
# Now there are more options
 
def combat(player,machine):
    if player == machine:
        return 0
    elif (player == "stone" and machine == "paper") or (player == "paper" and machine == "scissor") or (player == "scissor" and machine == "stone") or (player == "lizard" and machine == "stone") or (player == "spock" and machine == "lizard") or (player == "stone" and machine == "spock") or (player == "paper" and machine == "lizard") or (player == "scissor" and machine == "spock") or (player == "lizard" and machine == "scissor") or (player == "spock" and machine == "paper"):
        return 1
    else:
        return 2
    
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated

def game_progress(p,m):
    print("You chose", p, "and you have won", wins_player, "rounds")
    print("SkyNet chose", m, "and has won", wins_machine, "rounds")

    
# Create two variables that accumulate the wins of each participant

wins_player = 0
wins_machine = 0

# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.

while wins_player < num_games_to_win_for_win and wins_machine < num_games_to_win_for_win:
    player = players_choice()
    machine = random_machine()
    if combat(player,machine) == 1:
        wins_machine +=1
        game_progress (player,machine)
    elif combat(player,machine) == 2:
        wins_player +=1
        game_progress (player,machine)
    elif combat(player,machine) == 0:
        game_progress (player,machine)
        print("Nobody wins")

    
    
# Print by console the winner of the game based on who has more accumulated wins

if wins_player == num_games_to_win_for_win:
    print("The player wins!")
if wins_machine == num_games_to_win_for_win:
    print("SkyNet wins!")
# Out:
# How many games do you want to play?:3
# You have to win 2 games
# stone, paper, lizard, spock or scissor?:stone
# You chose stone and you have won 0 rounds
# SkyNet chose paper and has won 1 rounds
# stone, paper, lizard, spock or scissor?:stone
# You chose stone and you have won 0 rounds
# SkyNet chose stone and has won 1 rounds
# Nobody wins
# stone, paper, lizard, spock or scissor?:stone
# You chose stone and you have won 0 rounds
# SkyNet chose spock and has won 2 rounds
# SkyNet wins!
